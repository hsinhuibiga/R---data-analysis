# %% [markdown]
# #  5147 data wrangle

# %%
import pandas as pd

# %%
df_1= pd.read_csv('A.csv')

# %%
df_1
# Out:
#     Country Code                               Short Name  \
# 0            ABW                                    Aruba
# 1            AFG                              Afghanistan
# 2            AGO                                   Angola
# 3            ALB                                  Albania
# 4            AND                                  Andorra
# 5            ARB                               Arab World
# 6            ARE                     United Arab Emirates
# 7            ARG                                Argentina
# 8            ARM                                  Armenia
# 9            ASM                           American Samoa
# 10           ATG                      Antigua and Barbuda
# 11           AUS                                Australia
# 12           AUT                                  Austria
# 13           AZE                               Azerbaijan
# 14           BDI                                  Burundi
# ...

# %%
df_2= pd.read_csv('B.csv')

# %%
df_2.head()
# Out:
#                                               Series       Series Code  \
# 0  Share of female students in upper secondary ed...  UIS.GTVP.3.GPV.F
# 1  Share of female students in upper secondary ed...  UIS.GTVP.3.GPV.F
# 2  Share of female students in upper secondary ed...  UIS.GTVP.3.GPV.F
# 3  Share of female students in upper secondary ed...  UIS.GTVP.3.GPV.F
# 4  Share of female students in upper secondary ed...  UIS.GTVP.3.GPV.F
#
#                      Country Name Country Code 1990 [YR1990] 2000 [YR2000]  \
# 0                      Arab World          ARB            ..      68.52861
# 1          Caribbean small states          CSS            ..            ..
# 2  Central Europe and the Baltics          CEB            ..            ..
# 3      Early-demographic dividend          EAR            ..            ..
# 4             East Asia & Pacific          EAS            ..      58.88179
#
#   2055 [YR2055] 2060 [YR2060] 2065 [YR2065] 2070 [YR2070] 2075 [YR2075]  \
# ...

# %%
df_3= pd.read_csv('E.csv')

# %%
df_3
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean          High income
# 8            ARM       Europe & Central Asia  Upper middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
df_4=pd.read_csv('F.csv')

# %%
df_4
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  SE.PRM.CMPT.FE.ZS  Primary completion rate, female (% of relevant...
#
#                                          SOURCE_NOTE  \
# 0  Primary completion rate, or gross intake ratio...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  UNESCO Institute for Statistics (http://uis.un...         NaN

# %%
df_5=pd.read_excel('D.xls')

# %%
df_5
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df_6=pd.read_excel('GDP.xls')

# %%
df_6
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df_7=pd.read_excel('H.xlsx')

# %%
df_7
# Out:
#                                          GOING PLACES  \
# 0   Can a woman apply for a passport in the same w...
# 1   Can a woman legally travel outside the country...
# 2   Can a woman legally travel outside her home in...
# 3   Can a woman legally choose where to live in th...
# 4                                      STARTING A JOB
# 5   Can a woman get a job or pursue a trade or pro...
# 6   Does the law mandate nondiscrimination based o...
# 7   Is there legislation on sexual harassment in e...
# 8   Are there criminal penalties or civil remedies...
# 9                                        GETTING PAID
# 10  Does the law mandate equal remuneration for wo...
# 11        Can women work the same night hours as men?
# 12  Can women work in jobs deemed hazardous, arduo...
# 13  Are women able to work in the same industries ...
# 14                                    GETTING MARRIED
# 15  Is a married woman not legally required to obe...
# ...

# %%
df_8=pd.read_excel('W.xls')

# %%
df_8
# Out:
#                  economy wbcodev2                      Region  \
# 0            Afghanistan      AFG                  South Asia
# 1            Afghanistan      AFG                  South Asia
# 2            Afghanistan      AFG                  South Asia
# 3            Afghanistan      AFG                  South Asia
# 4            Afghanistan      AFG                  South Asia
# 5            Afghanistan      AFG                  South Asia
# 6            Afghanistan      AFG                  South Asia
# 7            Afghanistan      AFG                  South Asia
# 8            Afghanistan      AFG                  South Asia
# 9            Afghanistan      AFG                  South Asia
# 10               Albania      ALB       Europe & Central Asia
# 11               Albania      ALB       Europe & Central Asia
# 12               Albania      ALB       Europe & Central Asia
# 13               Albania      ALB       Europe & Central Asia
# ...

# %%
df_8.columns = ['Country Name','Country Code','Region','Income Group','Year','WBL Index','Going Places','Passport','Travel Abroad','Travel','live liberty','Start job','Job freedom','Work Gender','work safty','pentalty','pay check','same pay','same hour','social expect','industry','Marriage','obey','head','legistration','judgement','remarry','Children','paid leave','leave benefit','paternity leave','parental leave','dismissal','business','legal contract','register business','bank account','prohibit discrimination','assets','equal ownership','inherit','surviving spouses','equal authority','nonmonetary contributions','GETTING A PENSION','full pension','partial pension','retirement age','childcare']

# %%
df_8
# Out:
#             Country Name Country Code                      Region  \
# 0            Afghanistan          AFG                  South Asia
# 1            Afghanistan          AFG                  South Asia
# 2            Afghanistan          AFG                  South Asia
# 3            Afghanistan          AFG                  South Asia
# 4            Afghanistan          AFG                  South Asia
# 5            Afghanistan          AFG                  South Asia
# 6            Afghanistan          AFG                  South Asia
# 7            Afghanistan          AFG                  South Asia
# 8            Afghanistan          AFG                  South Asia
# 9            Afghanistan          AFG                  South Asia
# 10               Albania          ALB       Europe & Central Asia
# 11               Albania          ALB       Europe & Central Asia
# 12               Albania          ALB       Europe & Central Asia
# ...

# %%
df_9=pd.read_excel('GDP2.xls')

# %%
df_9
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df_GDP=pd.melt(df_9,id_vars=['Country Name','Country Code'], var_name=
               [ 'Year'],value_name='GDP')

# %%
df_GDP
# Out:
#                                            Country Name Country Code  Year  \
# 0                                                 Aruba          ABW  2009
# 1                                           Afghanistan          AFG  2009
# 2                                                Angola          AGO  2009
# 3                                               Albania          ALB  2009
# 4                                               Andorra          AND  2009
# 5                                            Arab World          ARB  2009
# 6                                  United Arab Emirates          ARE  2009
# 7                                             Argentina          ARG  2009
# 8                                               Armenia          ARM  2009
# 9                                        American Samoa          ASM  2009
# 10                                  Antigua and Barbuda          ATG  2009
# ...

# %%
df_10 = pd.merge(df_8, df_GDP, on=['Country Name','Country Code','Year'])

# %%
df_10
# Out:
#             Country Name Country Code                      Region  \
# 0            Afghanistan          AFG                  South Asia
# 1            Afghanistan          AFG                  South Asia
# 2            Afghanistan          AFG                  South Asia
# 3            Afghanistan          AFG                  South Asia
# 4            Afghanistan          AFG                  South Asia
# 5            Afghanistan          AFG                  South Asia
# 6            Afghanistan          AFG                  South Asia
# 7            Afghanistan          AFG                  South Asia
# 8            Afghanistan          AFG                  South Asia
# 9                Albania          ALB       Europe & Central Asia
# 10               Albania          ALB       Europe & Central Asia
# 11               Albania          ALB       Europe & Central Asia
# 12               Albania          ALB       Europe & Central Asia
# ...

# %%
df_10.to_csv("GDP.csv")

# %%
df_11=pd.read_excel('D1.xls')

# %%
df_Lit=pd.melt(df_11,id_vars=['Country Name','Country Code'], var_name=
               [ 'Year'],value_name='Literacy')

# %%
df_Lit
# Out:
#                                            Country Name Country Code  Year  \
# 0                                                 Aruba          ABW  2009
# 1                                           Afghanistan          AFG  2009
# 2                                                Angola          AGO  2009
# 3                                               Albania          ALB  2009
# 4                                               Andorra          AND  2009
# 5                                            Arab World          ARB  2009
# 6                                  United Arab Emirates          ARE  2009
# 7                                             Argentina          ARG  2009
# 8                                               Armenia          ARM  2009
# 9                                        American Samoa          ASM  2009
# 10                                  Antigua and Barbuda          ATG  2009
# ...

# %%
df_all = pd.merge(df_10, df_Lit, on=['Country Name','Country Code','Year'])

# %%
df_all
# Out:
#             Country Name Country Code                      Region  \
# 0            Afghanistan          AFG                  South Asia
# 1            Afghanistan          AFG                  South Asia
# 2            Afghanistan          AFG                  South Asia
# 3            Afghanistan          AFG                  South Asia
# 4            Afghanistan          AFG                  South Asia
# 5            Afghanistan          AFG                  South Asia
# 6            Afghanistan          AFG                  South Asia
# 7            Afghanistan          AFG                  South Asia
# 8            Afghanistan          AFG                  South Asia
# 9                Albania          ALB       Europe & Central Asia
# 10               Albania          ALB       Europe & Central Asia
# 11               Albania          ALB       Europe & Central Asia
# 12               Albania          ALB       Europe & Central Asia
# ...

# %%
df_all.to_csv("tab.csv")
